# %% [markdown]
# <a href="https://colab.research.google.com/github/simplyEmmanuel/simplyEmmanuel/blob/main/DataProjectLabII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Topic:**
#
# Assessing the Correlation Between Faculty Doctoral Qualifications and University Acceptance Rates: A Comprehensive Study of Higher Education Institutions.

# %% [markdown]
# # **Introduction:**
#
# In the realm of higher education, there exists a significant level of rivalry, not only among individuals seeking admission but also among institutions aiming to achieve academic superiority and renown. The reputation of a university is mostly determined by the quality of its professors, which is often measured by their scholarly qualifications.
#
# This study examines the crucial significance of faculty qualifications, specifically the number of educators with PhD degrees, as a possible factor influencing university acceptance rates. The hypothesis suggests that colleges with a greater proportion of faculty members who hold doctorate degrees may be associated with more rigorous admission procedures, indicating a dedication to maintaining exceptional academic criteria.
#
# This project summary seeks to analyze the complex relationship between faculty qualities and a university's selectivity, offering insights into how these elements interact to influence the institution's reputation and attractiveness to potential students. Amidst the ongoing effort of universities to find a middle ground between being inclusive and selective, it is essential to comprehend the impact of faculty credentials within the larger framework of educational policy and institution branding.

# %% [markdown]
# # **Background**
#
# The admission rates of universities are an important measure in the field of higher education. They differ greatly among schools and influence how selective and prestigious they are seen to be. As an example, Ivy League universities in the United States have acceptance rates as low as 4-7% - [CBS News](https://www.cbsnews.com/news/covid-pandemic-ivy-league-acceptance-rate-low/), indicating a more selective strategy. On the other hand, many public universities have acceptance rates higher than 50%, showing a more inclusive approach. These differences highlight the variety of educational beliefs and the specific groups of people that are being focused on.
#
# The literature on university admission rates emphasizes a wide range of factors that have an impact, including institutional resources, mission statements, student demographics, and societal trends. Research published in esteemed journals like The Review of Higher Education and Research in Higher Education consistently highlight the complex nature of admissions procedures, indicating that factors such as historical prestige, financial assistance options, and academic offerings have a substantial impact on acceptance rates.
#
# The significance of faculty credentials lies in the fact that PhD-qualified professors are widely regarded as the benchmark, possessing extensive knowledge and research proficiency that is anticipated to result in exceptional education and groundbreaking advancements. The significance of such faculty extends beyond academia; it also serves as a symbol, enhancing a university's reputation as a stronghold of advanced education and scholarly pursuits.
#
# Prior research, including studies published in the Journal of Higher Education, demonstrates a connection between the qualities of faculty members and the level of selectivity of universities([research article)](https://files.eric.ed.gov/fulltext/ED491002.pdf). Universities that have a greater percentage of faculty members with doctoral qualifications are often seen as offering a more demanding academic atmosphere. This tends to attract highly talented students and, consequently, leads to the implementation of more stringent admission standards. Comparative analyses in educational policy research go deeper into this relationship, specifically focusing on how faculty credentials significantly influence the strategic direction and competitive positioning of higher education institutions.

# %% [markdown]
# # **Import Libraries**
#
# First, import all the necessary modules using the import function. For this project, we will be mainly using pandas. To learn more about these packages, you can read through the documentation:
#
# *   https://pandas.pydata.org/
# *   https://numpy.org/
# *   https://matplotlib.org/

# %%
# Let's import the relevant Python packages here
# Feel free to import any other packages for this project

#Data Wrangling
import numpy as np
import pandas as pd

#Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # **Methodology:**
#
# This project is based on the use of strong data analysis techniques, and a further exploratory data analysis that extract the subtle details and connections within the College dataset. In the previous exercise, we utilized a blend of statistical techniques to analyze the correlations between faculty credentials, as shown by the proportion of faculty members holding PhD degrees, and the rates at which universities accept students.
#
# **Correlation study:** In order to gain an initial comprehension of the connection between faculty credentials and admission rates, we performed a correlation study. This statistical tool facilitated the quantification of the magnitude and orientation of the linear correlation between these two continuous variables.
#
# **Regression Models:** In order to further investigate the ability of faculty qualities to predict acceptance rates, we employed regression models. By accounting for potential confounders, we were able to quantify the link and make inferences about causality, given specific assumptions.

# %% [markdown]
# # **Project**
#
# ### Data
#
# This project summary uses the `College.csv` as we further explore the dataset. This dataset contains the following variables
# from 777 different universities and colleges in the US:
#
#
# | Column | Description |
# |:-|:-|
# |Private | Public/private indicator|
# |Apps | Number of applications received|
# |Accept | Number of applicants accepted|
# |Enroll | Number of new students enrolled|
# |Top10perc | New students from top 10\% of high school class|
# |Top25perc | New students from top 25\% of high school class|
# |F.Undergrad | Number of full-time undergraduates|
# |P.Undergrad | Number of part-time undergraduates|
# |Outstate | Out-of-state tuition|
# |Room.Board | Room and board costs|
# |Books | Estimated book costs|
# |Personal | Estimated personal spending|
# |PhD | Percent of faculty with Ph.D.’s|
# |Terminal | Percent of faculty with terminal degree|
# |S.F.Ratio | Student/faculty ratio|
# |Perc.alumni | Percent of alumni who donate|
# |Expend | Instructional expenditure per student|
# |Grad.Rate | Graduation rate|

# %% [markdown]
# **Data Processing:**
#
# The data processing stage is crucial in guaranteeing the integrity and validity of our findings. The actions undertaken is as subsequent:
#
# **Data Cleaning:** Upon preliminary examination, it was evident that the College dataset needed to undergo cleaning in order to rectify anomalies and address missing information. To ensure consistency and prevent division by zero when calculating the acceptance rate, we substituted any missing or zero values in the 'Apps' column with the average number of applications, converted the "Names" column into a dataframe index. The code is included below:

# %%
###Let's load the College dataset using pandas and name the variable college_df
# To read this file into a pandas DataFrame
college_df = pd.read_csv('/content/College.csv')

###Displaying the first few rows of the College dataset
college_head = college_df.head()
college_head
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate                         Names
# ...

# %%
###Let's set the 'Names' column as the index of the DataFrame
college_df = college_df.set_index('Names')  # This method will convert the 'Names' column into the DataFrame's index

###To examine the duplicates in the College dataset
duplicates = college_df.duplicated().sum()

### let's now drop the duplicates if any are found
if duplicates > 0:
  college_df = college_df.drop_duplicates()

duplicates, college_df.shape
# Out:
# (0, (777, 18))

# %% [markdown]
# **Feature Engineering:** A novel feature, acceptance_rate, was created by performing a division operation between the 'Accept' column and the 'Apps' column. This statistic played a crucial role in our investigation. In addition, we converted the 'Top10perc' column into a binary variable to classify colleges into two categories: those with percentages of top students above the average and those with percentages below the average.
#
# **Data Transformation:** To address variables with skewed distributions, such as 'Apps' and 'Accept', we employed log transformations to achieve data normalization. This is a widely adopted approach to fulfill the requirements of regression analysis.
#
# **Data Segmentation:** The dataset was partitioned into subsets based on the 'Private' variable in order to assess the influence of faculty credentials on admission rates in private and public institutions.
#
# Throughout this process, meticulous attention was given to preserving the integrity of the original dataset. All alterations were performed on a duplicate of the dataset, ensuring that the original data remains intact for future reference and verification.

# %%
### Let's rename our columns
college_df = college_df.rename(columns = {'Grad.Rate':'Grad_Rate',
                              'S.F.Ratio': 'S_F_Ratio',
                              'perc.alumni':'perc_alumni',
                              'Room.Board':'Room_Board',
                              'F.Undergrad':'F_Undergrad',
                              'P.Undergrad':'P_Undergrad',
                              'PhD': 'PhD_percentage'})

# %% [markdown]
# # **Findings**
#
# Descriptive Statistics.
# It is important to report the average percentage of PhD faculties and acceptance rates across the dataset. Hence, to answer the question, we have;

# %%
# Calculating the acceptance rate
college_df['acceptance_rate'] = college_df['Accept'] / college_df['Apps']

# Calculating descriptive statistics for PhD percentage and acceptance rate
average_phd = college_df['PhD_percentage'].mean()
average_acceptance_rate = college_df['acceptance_rate'].mean()

average_phd, average_acceptance_rate

### The average percentage of faculty with Ph.D. degrees across the universities
### in the dataset is approximately 72.66%. Additionally, the average acceptance
### rate for these universities is about 74.69%.
# Out:
# (72.66023166023166, 0.7469277072775414)

# %% [markdown]
#  1. What then is the correlation between the percentage of faculty with Ph.D. qualifications (PhD_percentage) and the acceptance rates (Accept/Apps ratio) at universities?

# %%
# Scatter plot to visualize the relationship between the percentage of faculty with Ph.D.'s and acceptance rate
plt.figure(figsize=(10, 6))
sns.scatterplot(x=college_df['PhD_percentage'], y=college_df['acceptance_rate'])

plt.title('Relationship Between Faculty with Ph.D. Qualifications and Acceptance Rates')
plt.xlabel('Percentage of Faculty with Ph.D.')
plt.ylabel('Acceptance Rate')
plt.show()

# Calculating the correlation coefficient between PhD percentage and acceptance rate
phd_acceptance_correlation = college_df['PhD_percentage'].corr(college_df['acceptance_rate'])
phd_acceptance_correlation
# Out:
# -0.318333939505444

# %% [markdown]
# The scatter plot depicts the dispersion of universities according to the proportion of faculty members possessing Ph.D. credentials in relation to their acceptance rates. The plot demonstrates a clear negative correlation between the percentage of faculty with Ph.D. degrees and the admission rate at institutions.
#
# The observed pattern aligns with a moderate negative correlation, as evidenced by the correlation coefficient of around -0.318. This implies that colleges with a greater percentage of highly skilled faculty members are likely to have a more rigorous admissions process. It suggests that these colleges maintain a high level of education that may appeal to a larger number of applicants, resulting in lower acceptance rates due to heightened competition, or that they have more rigorous admissions requirements that align with faculty qualities.
#
#
# Within the research project, this data provides evidence that the credentials of professors, particularly the percentage of faculty members holding Ph.D. degrees, may influence the level of selectivity of a school, as indicated by its acceptance rate. This is consistent with the project's objective to comprehend the dynamics of university admittance in connection to faculty qualities.

# %% [markdown]
# 2. How do the acceptance rates of private versus public universities differ when stratified by the percentage of faculty with Ph.D. qualifications?
#
# For this analysis, we shall categorize universities into two groups depending on their 'Private' status. Within each group, we will employ a box plot to contrast the admission rates of colleges that had percentages of faculty with Ph.D. qualifications above the median with those below the median. This will enable us to determine if the pattern identified in the entire dataset remains consistent when examining commercial and public institutions individually.

# %%
# Let's ensure that the 'PhD_category' and 'Institution_Type' columns are created in the DataFrame

# Recalculate the median percentage of faculty with Ph.D.
median_phd_percentage = college_df['PhD_percentage'].median()

# create the 'PhD_category' column based on the 'PhD_percentage column'
college_df['PhD_category'] = college_df['PhD_percentage'].apply(lambda x: 'Above Median' if x >= median_phd_percentage else 'Below Median')

# create the 'Institution_Type' column based on the 'Private' column
college_df['Institution_Type'] = college_df['Private'].apply(lambda x: 'Private' if x == 'Yes' else 'Public')

# Now let's create the box plot
plt.figure(figsize=(14, 7))
sns.boxplot(x='Institution_Type', y='acceptance_rate', hue='PhD_category', data=college_df, palette="Set3")

plt.title('Acceptance Rates for Private vs. Public Universities Categorized by PhD Qualifications')
plt.xlabel('Institution Type')
plt.ylabel('Acceptance Rate')
plt.legend(title='PhD Qualification Category')
plt.show()

# %% [markdown]
# The box plot illustrates the admission rates of private and public colleges, classified based on the percentage of faculty members with Ph.D. degrees, either above or below the median value.
#
# Based on the plot, we may discern multiple vital observations:
#
# Private institutions with Ph.D. qualifications above the median tend to exhibit lower acceptance rates than those with qualifications below the median. This implies that private colleges with a more significant percentage of faculty members with Ph.D. qualifications may have a more rigorous selection process.
#
# Public universities exhibit an identical pattern, wherein institutions with Ph.D. qualifications above the median also tend to have lower acceptance rates. Nevertheless, the disparity between the PhD. categories above and below the median is less significant for public than private universities.
# The acceptance rates for private institutions tend to be lower than those for public universities, suggesting that private universities are generally more scrutinizing in their admissions process, regardless of the qualifications of their professors.
#
# Outliers exist in all categories, suggesting that certain universities have unusually high or low acceptance rates. These rates may be impacted by variables unrelated to the fraction of faculty members with PhD. qualifications.
# These observations support the notion that the credentials of faculty members, particularly the proportion of professors holding PhD. degrees, are linked to the rates at which universities accept students. Moreover, the admission rates are influenced by the institution's nature, whether private or public, with private colleges generally exhibiting higher levels of selectivity. This detailed study offers further insights that align with the research topic's purpose.

# %% [markdown]
# 3. How does the distribution of applications (Apps) differ between universities with high versus low percentages of faculty with Ph.D. qualifications? And is there a difference in the enrollment patterns (Enroll) in universities with a higher proportion of Ph.D. qualified faculty compared to those with fewer Ph.D. holders?

# %%
# Distribution of applications (Apps) between universities with high vs. low percentages of faculty with Ph.D. qualifications.

# First, we can calculate the median percentage of faculty with Ph.D. again for clarity
median_phd_percentage = college_df['PhD_percentage'].median()

# Create a new column to categorize the universities based on Ph.D. percentage
college_df['PhD_category'] = college_df['PhD_percentage'].apply(lambda x: 'Above Median' if x >= median_phd_percentage else 'Below Median')

# Create histograms for the distribution of applications received by universities
plt.figure(figsize=(14, 7))
sns.histplot(data=college_df, x='Apps', hue='PhD_category', element='step', stat='density', common_norm=False)
plt.title('Distribution of Applications Based on Faculty Ph.D. Qualifications')
plt.xlabel('Number of Applications Received')
plt.ylabel('Density')
plt.legend(title='PhD Qualification Category')
plt.show()

# To the other part of the question, Distribution of new student enrollment numbers (Enroll)
# between universities with high vs. low percentages of faculty with Ph.D. qualifications.

# Let's create histograms for the distribution of new student enrollments
plt.figure(figsize=(14, 7))
sns.histplot(data=college_df, x='Enroll', hue='PhD_category', element='step', stat='density', common_norm=False)
plt.title('Distribution of New Student Enrollments Based on Faculty Ph.D. Qualifications')
plt.xlabel('Number of New Students Enrolled')
plt.ylabel('Density')
plt.legend(title='PhD Qualification Category')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Histograms have been created for the distribution of applications received (Apps) and the distribution of new student enrollments (Enroll), classified based on the percentage of instructors with Ph.D. qualifications (above or below the median).
#
# Based on the histograms, the following observations can be made:
#
# Applications Distribution: The histogram depicting the number of applications reveals that universities with a faculty composition where the percentage of Ph.D.-qualified staff falls below the median tend to exhibit a broader spread of application numbers. This suggests greater unpredictability in the quantity of applications they receive. Nevertheless, it is noteworthy that both groups reach their highest point at the lower end of the application spectrum, indicating that most universities tend to receive a comparatively limited number of applications, regardless of faculty qualifications.
#
# Enrollment Distribution: The histogram representing the number of new students enrolled shows that most universities have a deficient number of students. However, the distribution is slightly more dispersed for universities with a below-average percentage of faculty members qualified with a Ph.D. This indicates fluctuations in the number of students enrolled, which could be attributed to several factors, such as the size of the university, the availability of programs, and potentially the qualities of the professors.
#
# Both distributions exhibit right-skewness, showing that a minority of colleges attract a disproportionately high number of applications or enroll a significant number of students compared to the majority.
#
# These visualizations offer a first investigation into the potential correlation between the academic qualities of the professors and the applications and enrollments. Further analysis using statistical tests would be necessary to determine the relevance of these findings.

# %% [markdown]
# **Statistical Analysis**
#
# These visualizations suggest a relationship between applications and enrollments and faculty academic qualities, which may be tested statistically to determine their significance.
#
# Regression analysis can help us understand the relationship between applications, enrollments, and faculty credentials. We can examine:
# 1.   Linear regression to see if there's a predictive relationship between the percentage of faculty with Ph.D. qualifications and the number of applications received.
# 2.   Also, to explore if the percentage of faculty with Ph.D. qualifications predicts the number of new student enrollments.

# %%
from scipy.stats import pearsonr
import statsmodels.api as sm

# Prepare the data for regression analysis
X_apps = sm.add_constant(college_df['PhD_percentage'])  # Predictor variable for Apps
Y_apps = college_df['Apps']  # Response variable for Apps

X_enroll = sm.add_constant(college_df['PhD_percentage'])  # Predictor variable for Enroll
Y_enroll = college_df['Enroll']  # Response variable for Enroll

# Perform linear regression for Apps
model_apps = sm.OLS(Y_apps, X_apps).fit()

# Perform linear regression for Enroll
model_enroll = sm.OLS(Y_enroll, X_enroll).fit()

# Get the regression summary for Apps
summary_apps = model_apps.summary()

# Get the regression summary for Enroll
summary_enroll = model_enroll.summary()

summary_apps, summary_enroll
# Out:
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
# ...
#  Dep. Variable:                   Apps   R-squared:                       0.153
#  Model:                            OLS   Adj. R-squared:                  0.152
#  Method:                 Least Squares   F-statistic:                     139.6
#  Date:                Mon, 05 Feb 2024   Prob (F-statistic):           9.72e-30
#  Time:                        01:08:52   Log-Likelihood:                -7456.5
#  No. Observations:                 777   AIC:                         1.492e+04
#  Df Residuals:                     775   BIC:                         1.493e+04
#  Df Model:                           1
#  Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
#  ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Regression Analysis (Apps):**
#
# Since the R-squared value is 0.153, the percentage of Ph.D.-qualified teachers explains 15.3% of the application variation.
# The regression coefficient for Ph.D. % is positive, illustrating that as the percentage of Ph.D.-qualified faculty rises, so do applications.
#
# **Regression analysis (Enroll):**
#
# The R-squared result is 0.110, indicating that Ph.D.-qualified instructors explain 11% of new student enrollments.
# Similar to applications, the regression coefficient for Ph.D. % is positive, implying that colleges with more Ph.D.-holding faculty enroll more students.
#
# **Conclusion:**
#
# These findings indicate an association between the academic credentials of instructors, the number of applications received, and the number of new students enrolled. The positive regression coefficients indicate a pattern in which universities with more faculty members holding Ph.D. degrees tend to receive more applications and have a more significant number of enrolled students. However, it is crucial to acknowledge that some additional factors not accounted for in this analysis could substantially influence these results.

# %% [markdown]
# # **Challenges & Future Steps:**
#
# **Data Limitations:**
#
# *   The dataset has a restricted range of variables, mostly centered around
# undergraduate admissions, faculty qualifications, and fundamental financial factors. It exhibits a deficiency in certain aspects, including as postgraduate programs, research capacities, and broader institutional measures.
# *   Possible Bias in Data Collection: The dataset encompasses solely 777 universities, thereby failing to encompass the whole range of variety among higher education institutions in the United States, particularly smaller or specialized schools. This constraint has the potential to result in partiality in the analysis.
# *   Temporal static refers to the interference or disruption of temporal patterns or sequences. Observation: The dataset seems to depict a singular moment in time. The lack of longitudinal data limits the capacity to examine long-term patterns or evaluate the influence of modifications in university policy or external influences.
# *   Absence of Diversity and inclusion Metrics: Crucial aspects such as the representation of diverse students and faculty, efforts to promote inclusion, and activities aimed at engaging with the wider community are not incorporated, potentially exerting a substantial influence on the dynamics of the university.
# *   The absence of comprehensive geographic and demographic data regarding students and faculty hinders the capacity to examine regional patterns or assess the influence of demographic diversity on university dynamics.

# %% [markdown]
# # **Further Research:**
#
# *   The inclusion of research output and academic excellence: By including information on research publications, citations, and academic awards, we can gain a better understanding of the academic reputation and intellectual resources of institutions. This information may be indicative of the qualifications of the faculty and the appeal of the university.
# *   Enhanced Financial Metrics: In addition to the cost of tuition, incorporating information about university endowments, research funding, and financial aid can provide a more holistic assessment of the economic well-being and objectives of institutions.
# *   Conducting a longitudinal analysis involves gathering data over several years to examine trends and determine how changes in teacher credentials, admissions rules, and other factors influence a university's performance over time.
# *   Analyzing the role and expansion of online courses and technology-driven programs, particularly in light of the COVID-19 epidemic, is essential for trendy higher education evaluation.
# *   Student Success and Career Outcomes: Incorporating information regarding the rates of employment among graduates, the average incomes they start with, and the advancement of their careers could offer a more outcome-oriented evaluation of the quality of university education.

# %% [markdown]
# # **Conclusion:**
#
# **Summary of Insights:**
#
# > The analysis demonstrated a moderate inverse relationship between the proportion of faculty members holding Ph.D. qualifications and the rates at which universities accept students. These findings indicate that institutions with a more significant percentage of highly qualified faculty members are more likely to have a rigorous admissions process, which may indicate better academic criteria.
#
# The study found a direct relationship between the proportion of faculty members holding Ph.D. degrees, the number of applications received, and the number of new students who enrolled. This suggests that universities with a higher caliber of faculty members attract a more significant number of applicants and enroll a larger student body, potentially because of the perception of offering a superior level of education.
#
# Also, it revealed disparities in admission rates between private and public colleges when categorized based on faculty credentials. Private colleges typically exhibited lower acceptance rates, indicating a higher level of selectivity, which more highly qualified teachers further emphasized.
#
# In summary, the distribution of applications and enrollments can be observed through histograms, which reveal that most institutions, irrespective of faculty qualities, typically receive fewer applications and enroll fewer students. Nevertheless, universities with Ph.D. percentages below the median had more significant application numbers and enrollment fluctuations.

# %% [markdown]
# # **References**:
#
# Software and Tools Used:
# 1. **Google Colab for Data Analysis:** *An online platform used for Python programming, suitable for machine learning, data analysis, and education.*
#
# Dataset Sources:
# 1. Class materials and `College.csv`: The dataset `College.csv` and accompanying class materials provided by Professor Zi Bennie Yang, Ph.D.
#
# Literature and Previous Studies:
#
# 1. COVID Pandemic's Impact on Ivy League Acceptance Rate (https://www.cbsnews.com/news/covid-pandemic-ivy-league-acceptance-rate-low/): A news article discussing the impact of the COVID-19 pandemic on Ivy League acceptance rates.
#
# 2. ERIC Document on Higher Education (https://files.eric.ed.gov/fulltext/ED491002.pdf): A research paper or report from the Education Resources Information Center (ERIC), focusing on a topic related to higher education.
#
# Educational and Research Guidance:
# Project Lab by Professor Zi Bennie Yang, Ph.D. (https://harrisburgu.instructure.com/courses/12926/assignments/328076?module_item_id=1406474): Guidance and instructional material for the project lab, which could include methodology, theoretical frameworks, and analytical approaches.
